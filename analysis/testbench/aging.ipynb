# %%
from __future__ import print_function
import sys, json, os
import subprocess
import multiprocessing as mp
import numpy as np
from array import array

import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages

import ROOT
from ROOT import gROOT, gStyle, gDirectory, gPad

import constants
import crv_event
import crv_spill
import utils
import root_utils
import geometry
import geometry_constants
import filepath

topdir = os.path.dirname(os.path.abspath("__file__"))
analysis_dir = os.path.join(topdir,"analysis_root_files")

# fileListM127 = filepath.getfilelist(["crvaging001", "crvaging007"],"recoROOT",3)[0]
# fileListM127 = filepath.getfilelist(["crvaging001", "crvaging007"],"recoROOT",4)[0]
fileListM127 = filepath.getfilelist(["crvaging001", "crvaging007"],"recoROOT",5)[0]
fileListM127.sort(key=lambda x:(filepath.filenameparser(x,'run'), filepath.filenameparser(x,'subrun')))
# rootNameM127 = os.path.join(analysis_dir,"crvaging_module127_v003.root")
# rootNameM127 = os.path.join(analysis_dir,"crvaging_module127_v004.root")
rootNameM127 = os.path.join(analysis_dir,"crvaging_module127_v005.root")
# fileListM168 = filepath.getfilelist(["crvaging003", "crvaging004", "crvaging005", "crvaging006"],"recoROOT",3)[0]
# fileListM168 = filepath.getfilelist(["crvaging003", "crvaging004", "crvaging005", "crvaging006"],"recoROOT",4)[0]
fileListM168 = filepath.getfilelist(["crvaging003", "crvaging004", "crvaging005", "crvaging006"],"recoROOT",5)[0]
fileListM168.sort(key=lambda x:(filepath.filenameparser(x,'run'), filepath.filenameparser(x,'subrun')))
# rootNameM168 = os.path.join(analysis_dir,"crvaging_module168_v003.root")
# rootNameM168 = os.path.join(analysis_dir,"crvaging_module168_v004.root")
rootNameM168 = os.path.join(analysis_dir,"crvaging_module168_v005.root")
taskList = [(fileListM127, rootNameM127), (fileListM168, rootNameM168)]

def processFiles(fileList,rootName):
    analysisFile = ROOT.TFile(rootName, "RECREATE")
    analysisFile.mkdir("spectrum")
    analysisFile.cd()
    spill_summary_tree = ROOT.TTree('spill_summary','spill_summary')
    subrun_summary_tree = ROOT.TTree('subrun_summary','subrun_summary')
    spill_summary_entry_dict = root_utils.treeInitialization(spill_summary_tree, utils.spill_summary_branch_list)
    subrun_summary_entry_dict = root_utils.treeInitialization(subrun_summary_tree, utils.subrun_summary_branch_list)

    for filename in fileList:
        utils.processSubRun(filename, analysisFile, spill_summary_tree, subrun_summary_tree, spill_summary_entry_dict, subrun_summary_entry_dict, 
                            True, '== 0x0', False, "110", False) 
                            # applyManualDQC = True, dqmFilter = '== 0x0', dqmVerbose = False, spectrumTempCorrection = "110", weightedAvg = False
        
    analysisFile.cd()
    spill_summary_tree.Write()
    subrun_summary_tree.Write()
    analysisFile.Close()
    return

nWorker = 2
p = mp.Pool(processes=nWorker)
for taskspec in taskList:
    p.apply_async(processFiles, (taskspec[0],taskspec[1]))
p.close()
p.join()
# Out:
# Welcome to JupyROOT 6.28/04
# Reading file:Reading file:  rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.000066_000.rootrec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001059_000.root
#
# Run1059_000 processed 200/693 spills...
# Run0066_000 processed 200/1000 spills...
# Run1059_000 processed 400/693 spills...
# Run0066_000 processed 400/1000 spills...
# Run1059_000 processed 600/693 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001059_000.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001080_000.root
# Run0066_000 processed 600/1000 spills...
# Run1080_000 processed 200/499 spills...
# Run0066_000 processed 800/1000 spills...
# Run1080_000 processed 400/499 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.000066_000.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.000066_001.root
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001080_000.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001081_000.root
# Run0066_001 processed 200/943 spills...
# Run1081_000 processed 200/491 spills...
# Run0066_001 processed 400/943 spills...
# Run1081_000 processed 400/491 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001081_000.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001082_000.root
# Run0066_001 processed 600/943 spills...
# Run0066_001 processed 800/943 spills...
# Run1082_000 processed 200/507 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.000066_001.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.000094_000.root
# Run1082_000 processed 400/507 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001082_000.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001091_000.root
# Run0094_000 processed 200/1000 spills...
# Run1091_000 processed 200/1404 spills...
# Run0094_000 processed 400/1000 spills...
# Run1091_000 processed 400/1404 spills...
# Run0094_000 processed 600/1000 spills...
# Run1091_000 processed 600/1404 spills...
# Run0094_000 processed 800/1000 spills...
# Run1091_000 processed 800/1404 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.000094_000.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.000094_001.root
# Run1091_000 processed 1000/1404 spills...
# Run0094_001 processed 200/1000 spills...
# Run1091_000 processed 1200/1404 spills...
# Run0094_001 processed 400/1000 spills...
# Run1091_000 processed 1400/1404 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001091_000.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001116_000.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001137_000.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001138_000.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001146_000.root
# Run0094_001 processed 600/1000 spills...
# Run1146_000 processed 200/1826 spills...
# Run1146_000 processed 400/1826 spills...
# Run0094_001 processed 800/1000 spills...
# Run1146_000 processed 600/1826 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.000094_001.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.000094_002.root
# Run1146_000 processed 800/1826 spills...
# Run0094_002 processed 200/999 spills...
# Run1146_000 processed 1000/1826 spills...
# Run0094_002 processed 400/999 spills...
# Run1146_000 processed 1200/1826 spills...
# Run0094_002 processed 600/999 spills...
# Run1146_000 processed 1400/1826 spills...
# Run1146_000 processed 1600/1826 spills...
# Run0094_002 processed 800/999 spills...
# Run1146_000 processed 1800/1826 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001146_000.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001148_000.root
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.000094_002.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.000094_003.root
# Run1148_000 processed 200/1480 spills...
# Run0094_003 processed 200/1001 spills...
# Run1148_000 processed 400/1480 spills...
# Run0094_003 processed 400/1001 spills...
# Run1148_000 processed 600/1480 spills...
# Run1148_000 processed 800/1480 spills...
# Run0094_003 processed 600/1001 spills...
# Run1148_000 processed 1000/1480 spills...
# Run0094_003 processed 800/1001 spills...
# Run1148_000 processed 1200/1480 spills...
# Run0094_003 processed 1000/1001 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.000094_003.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.000094_004.root
# Run1148_000 processed 1400/1480 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001148_000.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001149_000.root
# Run0094_004 processed 200/1001 spills...
# Run1149_000 processed 200/1272 spills...
# Run0094_004 processed 400/1001 spills...
# Run1149_000 processed 400/1272 spills...
# Run0094_004 processed 600/1001 spills...
# Run1149_000 processed 600/1272 spills...
# Run0094_004 processed 800/1001 spills...
# Run1149_000 processed 800/1272 spills...
# Run0094_004 processed 1000/1001 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.000094_004.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.000094_005.root
# Run1149_000 processed 1000/1272 spills...
# Run0094_005 processed 200/1001 spills...
# Run1149_000 processed 1200/1272 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001149_000.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001150_000.root
# Run0094_005 processed 400/1001 spills...
# Run1150_000 processed 200/432 spills...
# *** WARNING: CRV_spill: __init__: Spill # 1 has bad time stamp
# !!! spill 0001 skipped; the spill has no valid timestamp; 0x17
# Run0094_005 processed 600/1001 spills...
# Run1150_000 processed 400/432 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001150_000.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001152_000.root
# Run0094_005 processed 800/1001 spills...
# Run1152_000 processed 200/430 spills...
# Run0094_005 processed 1000/1001 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.000094_005.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.000094_006.root
# Run1152_000 processed 400/430 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001152_000.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001154_000.root
# Run0094_006 processed 200/998 spills...
# Run1154_000 processed 200/442 spills...
# Run0094_006 processed 400/998 spills...
# Run1154_000 processed 400/442 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001154_000.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001159_000.root
# Run0094_006 processed 600/998 spills...
# Run1159_000 processed 200/1179 spills...
# Run0094_006 processed 800/998 spills...
# Run1159_000 processed 400/1179 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.000094_006.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.000094_007.root
# Run1159_000 processed 600/1179 spills...
# *** WARNING: CRV_spill: __init__: Spill # 0 has bad time stamp
# !!! spill 0000 skipped; the spill has no valid timestamp; 0x17
# Run0094_007 processed 200/1001 spills...
# Run1159_000 processed 800/1179 spills...
# Run0094_007 processed 400/1001 spills...
# *** WARNING: CRV_spill: __init__: Spill # 1 has bad time stamp
# !!! spill 0001 skipped; the spill has no valid timestamp; 0x17
# Run1159_000 processed 1000/1179 spills...
# Run0094_007 processed 600/1001 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001159_000.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001160_000.root
# Run0094_007 processed 800/1001 spills...
# Run1160_000 processed 200/494 spills...
# Run0094_007 processed 1000/1001 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.000094_007.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.000094_008.root
# Run1160_000 processed 400/494 spills...
# Run0094_008 processed 200/999 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001160_000.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001161_000.root
# Run0094_008 processed 400/999 spills...
# Run1161_000 processed 200/525 spills...
# Run0094_008 processed 600/999 spills...
# Run1161_000 processed 400/525 spills...
# *** offset between spillNumber and spillIndex realigned.
# *** offset between spillNumber and spillIndex realigned.
# *** offset between spillNumber and spillIndex realigned.
# *** offset between spillNumber and spillIndex realigned.
# *** offset between spillNumber and spillIndex realigned.
# Run0094_008 processed 800/999 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001161_000.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001167_000.root
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.000094_008.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.000094_009.root
# Run1167_000 processed 200/1418 spills...
# Run0094_009 processed 200/998 spills...
# Run1167_000 processed 400/1418 spills...
# Run0094_009 processed 400/998 spills...
# Run1167_000 processed 600/1418 spills...
# Run0094_009 processed 600/998 spills...
# Run1167_000 processed 800/1418 spills...
# Run1167_000 processed 1000/1418 spills...
# Run0094_009 processed 800/998 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.000094_009.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.000094_010.root
# Run1167_000 processed 1200/1418 spills...
# Run0094_010 processed 200/999 spills...
# Run1167_000 processed 1400/1418 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001167_000.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001168_000.root
# Run0094_010 processed 400/999 spills...
# Run1168_000 processed 200/977 spills...
# Run0094_010 processed 600/999 spills...
# Run1168_000 processed 400/977 spills...
# Run0094_010 processed 800/999 spills...
# Run1168_000 processed 600/977 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.000094_010.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.000094_011.root
# Run1168_000 processed 800/977 spills...
# Run0094_011 processed 200/1002 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001168_000.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001169_000.root
# Run0094_011 processed 400/1002 spills...
# Run1169_000 processed 200/826 spills...
# Run0094_011 processed 600/1002 spills...
# Run0094_011 processed 800/1002 spills...
# Run1169_000 processed 400/826 spills...
# Run0094_011 processed 1000/1002 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.000094_011.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.000094_012.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.000105_000.root
# Run1169_000 processed 600/826 spills...
# Run0105_000 processed 200/963 spills...
# Run0105_000 processed 400/963 spills...
# Run1169_000 processed 800/826 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001169_000.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001170_000.root
# Run0105_000 processed 600/963 spills...
# Run1170_000 processed 200/1088 spills...
# Run0105_000 processed 800/963 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.000105_000.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.000105_001.root
# Run1170_000 processed 400/1088 spills...
# Run0105_001 processed 200/999 spills...
# Run0105_001 processed 400/999 spills...
# Run1170_000 processed 600/1088 spills...
# Run0105_001 processed 600/999 spills...
# Run1170_000 processed 800/1088 spills...
# Run0105_001 processed 800/999 spills...
# *** offset between spillNumber and spillIndex realigned.
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.000105_001.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.000105_002.root
# Run1170_000 processed 1000/1088 spills...
# Run0105_002 processed 200/1000 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001170_000.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001171_000.root
# Run0105_002 processed 400/1000 spills...
# Run1171_000 processed 200/461 spills...
# Run0105_002 processed 600/1000 spills...
# Run0105_002 processed 800/1000 spills...
# Run1171_000 processed 400/461 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001171_000.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001177_000.root
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.000105_002.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.000105_003.root
# Run0105_003 processed 200/999 spills...
# Run0105_003 processed 400/999 spills...
# Run1177_000 processed 200/723 spills...
# Run0105_003 processed 600/999 spills...
# Run0105_003 processed 800/999 spills...
# Run1177_000 processed 400/723 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.000105_003.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.000105_004.root
# Run0105_004 processed 200/959 spills...
# Run1177_000 processed 600/723 spills...
# Run0105_004 processed 400/959 spills...
# Run0105_004 processed 600/959 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001177_000.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001181_000.root
# Run0105_004 processed 800/959 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.000105_004.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.000105_005.root
# Run0105_005 processed 200/1000 spills...
# Run1181_000 processed 200/979 spills...
# Run0105_005 processed 400/1000 spills...
# Run0105_005 processed 600/1000 spills...
# Run0105_005 processed 800/1000 spills...
# Run1181_000 processed 400/979 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.000105_005.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.000105_006.root
# Run0105_006 processed 200/956 spills...
# Run0105_006 processed 400/956 spills...
# Run1181_000 processed 600/979 spills...
# Run0105_006 processed 600/956 spills...
# *** offset between spillNumber and spillIndex realigned.
# Run0105_006 processed 800/956 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.000105_006.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.000105_007.root
# Run1181_000 processed 800/979 spills...
# Run0105_007 processed 200/968 spills...
# Run0105_007 processed 400/968 spills...
# Run0105_007 processed 600/968 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001181_000.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001212_000.root
# Run0105_007 processed 800/968 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.000105_007.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.000105_008.root
# Run0105_008 processed 200/1000 spills...
# Run1212_000 processed 200/1195 spills...
# Run0105_008 processed 400/1000 spills...
# Run0105_008 processed 600/1000 spills...
# Run0105_008 processed 800/1000 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.000105_008.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.000105_009.root
# Run1212_000 processed 400/1195 spills...
# Run0105_009 processed 200/994 spills...
# Run0105_009 processed 400/994 spills...
# Run0105_009 processed 600/994 spills...
# Run0105_009 processed 800/994 spills...
# Run1212_000 processed 600/1195 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.000105_009.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.000105_010.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.000119_000.root
# Run0119_000 processed 200/1353 spills...
# Run0119_000 processed 400/1353 spills...
# Run1212_000 processed 800/1195 spills...
# Run0119_000 processed 600/1353 spills...
# Run0119_000 processed 800/1353 spills...
# Run1212_000 processed 1000/1195 spills...
# Run0119_000 processed 1000/1353 spills...
# Run0119_000 processed 1200/1353 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.000119_000.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001010_000.root
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001212_000.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001212_001.root
# Run1010_000 processed 200/558 spills...
# Run1010_000 processed 400/558 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001010_000.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001020_000.root
# Run1212_001 processed 200/1188 spills...
# Run1020_000 processed 200/881 spills...
# Run1020_000 processed 400/881 spills...
# Run1020_000 processed 600/881 spills...
# Run1212_001 processed 400/1188 spills...
# Run1020_000 processed 800/881 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001020_000.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001021_000.root
# Run1021_000 processed 200/1538 spills...
# Run1212_001 processed 600/1188 spills...
# Run1021_000 processed 400/1538 spills...
# Run1021_000 processed 600/1538 spills...
# Run1021_000 processed 800/1538 spills...
# Run1212_001 processed 800/1188 spills...
# Run1021_000 processed 1000/1538 spills...
# Run1021_000 processed 1200/1538 spills...
# Run1212_001 processed 1000/1188 spills...
# Run1021_000 processed 1400/1538 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001021_000.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001022_000.root
# Run1022_000 processed 200/1000 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001212_001.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001217_000.root
# Run1022_000 processed 400/1000 spills...
# Run1217_000 processed 200/1748 spills...
# Run1022_000 processed 600/1000 spills...
# Run1022_000 processed 800/1000 spills...
# Run1217_000 processed 400/1748 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001022_000.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001022_001.root
# Run1022_001 processed 200/1000 spills...
# Run1217_000 processed 600/1748 spills...
# Run1022_001 processed 400/1000 spills...
# Run1022_001 processed 600/1000 spills...
# Run1217_000 processed 800/1748 spills...
# Run1022_001 processed 800/1000 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001022_001.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001022_002.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001031_000.root
# Run1217_000 processed 1000/1748 spills...
# Run1031_000 processed 200/515 spills...
# Run1031_000 processed 400/515 spills...
# Run1217_000 processed 1200/1748 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001031_000.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001033_000.root
# Run1033_000 processed 200/1000 spills...
# Run1217_000 processed 1400/1748 spills...
# Run1033_000 processed 400/1000 spills...
# Run1033_000 processed 600/1000 spills...
# Run1033_000 processed 800/1000 spills...
# Run1217_000 processed 1600/1748 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001033_000.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001033_001.root
# Run1033_001 processed 200/538 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001217_000.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001218_000.root
# Run1033_001 processed 400/538 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001033_001.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001034_000.root
# Run1034_000 processed 200/1000 spills...
# Run1218_000 processed 200/444 spills...
# Run1034_000 processed 400/1000 spills...
# Run1034_000 processed 600/1000 spills...
# Run1034_000 processed 800/1000 spills...
# Run1218_000 processed 400/444 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001218_000.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001219_000.root
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001034_000.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001034_001.root
# *** offset between spillNumber and spillIndex realigned.
# Run1034_001 processed 200/999 spills...
# Run1034_001 processed 400/999 spills...
# Run1219_000 processed 200/1042 spills...
# Run1034_001 processed 600/999 spills...
# Run1034_001 processed 800/999 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001034_001.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001034_002.root
# Run1219_000 processed 400/1042 spills...
# Run1034_002 processed 200/1000 spills...
# Run1034_002 processed 400/1000 spills...
# Run1219_000 processed 600/1042 spills...
# Run1034_002 processed 600/1000 spills...
# Run1034_002 processed 800/1000 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001034_002.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001034_003.root
# Run1219_000 processed 800/1042 spills...
# Run1034_003 processed 200/1000 spills...
# Run1034_003 processed 400/1000 spills...
# Run1219_000 processed 1000/1042 spills...
# Run1034_003 processed 600/1000 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001219_000.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001240_000.root
# Run1034_003 processed 800/1000 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001034_003.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001034_004.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001035_000.root
# Run1035_000 processed 200/978 spills...
# Run1240_000 processed 200/657 spills...
# Run1035_000 processed 400/978 spills...
# Run1035_000 processed 600/978 spills...
# Run1035_000 processed 800/978 spills...
# Run1240_000 processed 400/657 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001035_000.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001243_000.root
# Run1243_000 processed 200/655 spills...
# Run1240_000 processed 600/657 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001240_000.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001241_000.root
# Run1243_000 processed 400/655 spills...
# Run1243_000 processed 600/655 spills...
# Run1241_000 processed 200/548 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001243_000.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001244_000.root
# Run1244_000 processed 200/822 spills...
# Run1241_000 processed 400/548 spills...
# Run1244_000 processed 400/822 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001241_000.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001375_000.root
# Run1244_000 processed 600/822 spills...
# Run1375_000 processed 200/1305 spills...
# Run1244_000 processed 800/822 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001244_000.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001245_000.root
# Run1375_000 processed 400/1305 spills...
# Run1245_000 processed 200/924 spills...
# Run1245_000 processed 400/924 spills...
# Run1375_000 processed 600/1305 spills...
# Run1245_000 processed 600/924 spills...
# Run1245_000 processed 800/924 spills...
# Run1375_000 processed 800/1305 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001245_000.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001246_000.root
# Run1375_000 processed 1000/1305 spills...
# Run1246_000 processed 200/641 spills...
# Run1375_000 processed 1200/1305 spills...
# Run1246_000 processed 400/641 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001375_000.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001376_000.root
# Run1246_000 processed 600/641 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001246_000.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001247_000.root
# Run1376_000 processed 200/1001 spills...
# Run1247_000 processed 200/406 spills...
# Run1376_000 processed 400/1001 spills...
# Run1247_000 processed 400/406 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001247_000.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001248_000.root
# Run1248_000 processed 200/713 spills...
# Run1376_000 processed 600/1001 spills...
# Run1248_000 processed 400/713 spills...
# Run1376_000 processed 800/1001 spills...
# Run1248_000 processed 600/713 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001248_000.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001251_000.root
# Run1251_000 processed 200/855 spills...
# Run1376_000 processed 1000/1001 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001376_000.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001376_001.root
# Run1251_000 processed 400/855 spills...
# Run1376_001 processed 200/1001 spills...
# Run1251_000 processed 600/855 spills...
# Run1251_000 processed 800/855 spills...
# Run1376_001 processed 400/1001 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001251_000.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001262_000.root
# Run1262_000 processed 200/1489 spills...
# Run1376_001 processed 600/1001 spills...
# Run1262_000 processed 400/1489 spills...
# Run1376_001 processed 800/1001 spills...
# Run1262_000 processed 600/1489 spills...
# Run1376_001 processed 1000/1001 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001376_001.root
# Run1262_000 processed 800/1489 spills...Reading file:
# rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001379_000.root
# Run1262_000 processed 1000/1489 spills...
# Run1379_000 processed 200/1134 spills...
# Run1262_000 processed 1200/1489 spills...
# Run1379_000 processed 400/1134 spills...
# Run1262_000 processed 1400/1489 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001262_000.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001264_000.root
# Run1379_000 processed 600/1134 spills...
# Run1264_000 processed 200/1891 spills...
# Run1379_000 processed 800/1134 spills...
# Run1264_000 processed 400/1891 spills...
# Run1264_000 processed 600/1891 spills...
# Run1379_000 processed 1000/1134 spills...
# Run1264_000 processed 800/1891 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001379_000.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001380_000.root
# Run1264_000 processed 1000/1891 spills...
# Run1380_000 processed 200/1197 spills...
# Run1264_000 processed 1200/1891 spills...
# Run1380_000 processed 400/1197 spills...
# Run1264_000 processed 1400/1891 spills...
# Run1380_000 processed 600/1197 spills...
# Run1264_000 processed 1600/1891 spills...
# Run1380_000 processed 800/1197 spills...
# Run1264_000 processed 1800/1891 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001264_000.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001276_000.root
# Run1380_000 processed 1000/1197 spills...
# Run1276_000 processed 200/422 spills...
# Run1276_000 processed 400/422 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001380_000.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001400_000.root
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001276_000.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001279_000.root
# Run1279_000 processed 200/1002 spills...
# Run1279_000 processed 400/1002 spills...
# Run1279_000 processed 600/1002 spills...
# Run1279_000 processed 800/1002 spills...
# Run1279_000 processed 1000/1002 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001279_000.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001279_001.root
# Run1279_001 processed 200/1002 spills...
# Run1279_001 processed 400/1002 spills...
# Run1400_000 processed 200/1165 spills...
# Run1279_001 processed 600/1002 spills...
# Run1279_001 processed 800/1002 spills...
# Run1279_001 processed 1000/1002 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001279_001.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001279_002.root
# Run1279_002 processed 200/1002 spills...
# Run1279_002 processed 400/1002 spills...
# Run1279_002 processed 600/1002 spills...
# Run1279_002 processed 800/1002 spills...
# Run1279_002 processed 1000/1002 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001279_002.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001279_003.root
# Run1400_000 processed 400/1165 spills...
# Run1279_003 processed 200/1002 spills...
# Run1279_003 processed 400/1002 spills...
# Run1279_003 processed 600/1002 spills...
# Run1279_003 processed 800/1002 spills...
# Run1279_003 processed 1000/1002 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001279_003.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001279_004.root
# Run1279_004 processed 200/1002 spills...
# Run1279_004 processed 400/1002 spills...
# Run1279_004 processed 600/1002 spills...
# Run1400_000 processed 600/1165 spills...
# Run1279_004 processed 800/1002 spills...
# Run1279_004 processed 1000/1002 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001279_004.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001279_005.root
# Run1279_005 processed 200/1002 spills...
# Run1279_005 processed 400/1002 spills...
# Run1279_005 processed 600/1002 spills...
# Run1279_005 processed 800/1002 spills...
# Run1279_005 processed 1000/1002 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001279_005.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001279_006.root
# Run1279_006 processed 200/1002 spills...
# Run1400_000 processed 800/1165 spills...
# Run1279_006 processed 400/1002 spills...
# Run1279_006 processed 600/1002 spills...
# Run1279_006 processed 800/1002 spills...
# Run1279_006 processed 1000/1002 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001279_006.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001279_007.root
# Run1279_007 processed 200/996 spills...
# Run1279_007 processed 400/996 spills...
# Run1279_007 processed 600/996 spills...
# Run1400_000 processed 1000/1165 spills...
# Run1279_007 processed 800/996 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001279_007.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001280_000.root
# Run1280_000 processed 200/1309 spills...
# Run1280_000 processed 400/1309 spills...
# Run1280_000 processed 600/1309 spills...
# Run1280_000 processed 800/1309 spills...
# Run1280_000 processed 1000/1309 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001400_000.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001407_000.root
# Run1280_000 processed 1200/1309 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001280_000.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001280_001.root
# Run1280_001 processed 200/1309 spills...
# Run1280_001 processed 400/1309 spills...
# Run1280_001 processed 600/1309 spills...
# Run1280_001 processed 800/1309 spills...
# Run1280_001 processed 1000/1309 spills...
# Run1407_000 processed 200/1097 spills...
# Run1280_001 processed 1200/1309 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001280_001.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001280_002.root
# Run1280_002 processed 200/1307 spills...
# Run1280_002 processed 400/1307 spills...
# Run1280_002 processed 600/1307 spills...
# Run1280_002 processed 800/1307 spills...
# Run1280_002 processed 1000/1307 spills...
# Run1280_002 processed 1200/1307 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001280_002.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001281_000.root
# Run1407_000 processed 400/1097 spills...
# Run1281_000 processed 200/1025 spills...
# Run1281_000 processed 400/1025 spills...
# Run1281_000 processed 600/1025 spills...
# Run1281_000 processed 800/1025 spills...
# Run1281_000 processed 1000/1025 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001281_000.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001281_001.root
# Run1281_001 processed 200/1025 spills...
# Run1281_001 processed 400/1025 spills...
# Run1407_000 processed 600/1097 spills...
# Run1281_001 processed 600/1025 spills...
# Run1281_001 processed 800/1025 spills...
# Run1281_001 processed 1000/1025 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001281_001.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001281_002.root
# Run1281_002 processed 200/1025 spills...
# Run1281_002 processed 400/1025 spills...
# Run1281_002 processed 600/1025 spills...
# Run1281_002 processed 800/1025 spills...
# Run1407_000 processed 800/1097 spills...
# Run1281_002 processed 1000/1025 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001281_002.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001281_003.root
# Run1281_003 processed 200/1025 spills...
# Run1281_003 processed 400/1025 spills...
# Run1281_003 processed 600/1025 spills...
# Run1281_003 processed 800/1025 spills...
# Run1281_003 processed 1000/1025 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001281_003.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001281_004.root
# Run1281_004 processed 200/1025 spills...
# Run1407_000 processed 1000/1097 spills...
# Run1281_004 processed 400/1025 spills...
# Run1281_004 processed 600/1025 spills...
# Run1281_004 processed 800/1025 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001407_000.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001407_001.root
# Run1281_004 processed 1000/1025 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001281_004.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001281_005.root
# Run1281_005 processed 200/1023 spills...
# Run1281_005 processed 400/1023 spills...
# Run1281_005 processed 600/1023 spills...
# Run1281_005 processed 800/1023 spills...
# Run1281_005 processed 1000/1023 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001281_005.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001284_000.root
# Run1407_001 processed 200/1096 spills...
# Run1284_000 processed 200/1139 spills...
# Run1407_001 processed 400/1096 spills...
# Run1284_000 processed 400/1139 spills...
# Run1284_000 processed 600/1139 spills...
# Run1407_001 processed 600/1096 spills...
# Run1284_000 processed 800/1139 spills...
# Run1407_001 processed 800/1096 spills...
# Run1284_000 processed 1000/1139 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001284_000.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001284_001.root
# Run1407_001 processed 1000/1096 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001407_001.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001407_002.root
# Run1284_001 processed 200/1138 spills...
# Run1407_002 processed 200/1094 spills...
# Run1284_001 processed 400/1138 spills...
# Run1284_001 processed 600/1138 spills...
# Run1407_002 processed 400/1094 spills...
# Run1284_001 processed 800/1138 spills...
# Run1407_002 processed 600/1094 spills...
# Run1284_001 processed 1000/1138 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001284_001.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001285_000.root
# Run1407_002 processed 800/1094 spills...
# Run1407_002 processed 1000/1094 spills...
# Run1285_000 processed 200/1466 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001407_002.root
# Run1285_000 processed 400/1466 spills...
# Run1285_000 processed 600/1466 spills...
# Run1285_000 processed 800/1466 spills...
# Run1285_000 processed 1000/1466 spills...
# Run1285_000 processed 1200/1466 spills...
# Run1285_000 processed 1400/1466 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001285_000.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001285_001.root
# Run1285_001 processed 200/1466 spills...
# Run1285_001 processed 400/1466 spills...
# Run1285_001 processed 600/1466 spills...
# Run1285_001 processed 800/1466 spills...
# Run1285_001 processed 1000/1466 spills...
# Run1285_001 processed 1200/1466 spills...
# Run1285_001 processed 1400/1466 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001285_001.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001286_000.root
# Run1286_000 processed 200/505 spills...
# Run1286_000 processed 400/505 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001286_000.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001287_000.root
# Run1287_000 processed 200/1909 spills...
# Run1287_000 processed 400/1909 spills...
# Run1287_000 processed 600/1909 spills...
# Run1287_000 processed 800/1909 spills...
# Run1287_000 processed 1000/1909 spills...
# Run1287_000 processed 1200/1909 spills...
# Run1287_000 processed 1400/1909 spills...
# Run1287_000 processed 1600/1909 spills...
# Run1287_000 processed 1800/1909 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001287_000.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001288_000.root
# Run1288_000 processed 200/887 spills...
# Run1288_000 processed 400/887 spills...
# Run1288_000 processed 600/887 spills...
# Run1288_000 processed 800/887 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001288_000.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001312_000.root
# Run1312_000 processed 200/1082 spills...
# Run1312_000 processed 400/1082 spills...
# Run1312_000 processed 600/1082 spills...
# Run1312_000 processed 800/1082 spills...
# Run1312_000 processed 1000/1082 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001312_000.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001312_001.root
# Run1312_001 processed 200/1082 spills...
# Run1312_001 processed 400/1082 spills...
# Run1312_001 processed 600/1082 spills...
# Run1312_001 processed 800/1082 spills...
# Run1312_001 processed 1000/1082 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001312_001.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001312_002.root
# Run1312_002 processed 200/1083 spills...
# Run1312_002 processed 400/1083 spills...
# Run1312_002 processed 600/1083 spills...
# Run1312_002 processed 800/1083 spills...
# Run1312_002 processed 1000/1083 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001312_002.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001315_000.root
# Run1315_000 processed 200/1131 spills...
# Run1315_000 processed 400/1131 spills...
# Run1315_000 processed 600/1131 spills...
# Run1315_000 processed 800/1131 spills...
# Run1315_000 processed 1000/1131 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001315_000.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001315_001.root
# Run1315_001 processed 200/1132 spills...
# Run1315_001 processed 400/1132 spills...
# Run1315_001 processed 600/1132 spills...
# Run1315_001 processed 800/1132 spills...
# Run1315_001 processed 1000/1132 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001315_001.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001327_000.root
# Run1327_000 processed 200/1029 spills...
# Run1327_000 processed 400/1029 spills...
# Run1327_000 processed 600/1029 spills...
# Run1327_000 processed 800/1029 spills...
# Run1327_000 processed 1000/1029 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001327_000.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001341_000.root
# Run1341_000 processed 200/1026 spills...
# Run1341_000 processed 400/1026 spills...
# Run1341_000 processed 600/1026 spills...
# Run1341_000 processed 800/1026 spills...
# Run1341_000 processed 1000/1026 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001341_000.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001341_001.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001341_002.root
# Run1341_002 processed 200/1026 spills...
# Run1341_002 processed 400/1026 spills...
# Run1341_002 processed 600/1026 spills...
# Run1341_002 processed 800/1026 spills...
# Run1341_002 processed 1000/1026 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001341_002.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001341_003.root
# Run1341_003 processed 200/1026 spills...
# Run1341_003 processed 400/1026 spills...
# Run1341_003 processed 600/1026 spills...
# Run1341_003 processed 800/1026 spills...
# Run1341_003 processed 1000/1026 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001341_003.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001341_004.root
# Run1341_004 processed 200/1026 spills...
# Run1341_004 processed 400/1026 spills...
# Run1341_004 processed 600/1026 spills...
# Run1341_004 processed 800/1026 spills...
# Run1341_004 processed 1000/1026 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001341_004.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001341_005.root
# Run1341_005 processed 200/1030 spills...
# Run1341_005 processed 400/1030 spills...
# Run1341_005 processed 600/1030 spills...
# Run1341_005 processed 800/1030 spills...
# Run1341_005 processed 1000/1030 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001341_005.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001354_000.root
# Run1354_000 processed 200/1117 spills...
# Run1354_000 processed 400/1117 spills...
# Run1354_000 processed 600/1117 spills...
# Run1354_000 processed 800/1117 spills...
# Run1354_000 processed 1000/1117 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001354_000.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001354_001.root
# Run1354_001 processed 200/1118 spills...
# Run1354_001 processed 400/1118 spills...
# Run1354_001 processed 600/1118 spills...
# Run1354_001 processed 800/1118 spills...
# Run1354_001 processed 1000/1118 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001354_001.root
# Reading file: rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001370_000.root
# Run1370_000 processed 200/1368 spills...
# Run1370_000 processed 400/1368 spills...
# Run1370_000 processed 600/1368 spills...
# Run1370_000 processed 800/1368 spills...
# Run1370_000 processed 1000/1368 spills...
# Run1370_000 processed 1200/1368 spills...
# Loading calibration information from rec.mu2e.CRV_wideband_cosmics.CRVWB-000-005-000.001370_000.root

# %%
from __future__ import print_function
import sys, json, os
import subprocess
import multiprocessing as mp
import numpy as np
from array import array

lock = mp.Manager().Lock()

import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages

import ROOT
from ROOT import gROOT, gStyle, gDirectory, gPad

import constants
import crv_event
import crv_spill
import utils
import root_utils
import geometry
import geometry_constants
import filepath
import manualDQC

gROOT.Reset()
gROOT.SetBatch(1)
gROOT.ProcessLine( "gErrorIgnoreLevel = 1001;")
gStyle.SetOptStat(111110)
gStyle.SetOptFit(0)
gStyle.SetLineScalePS(0.3)

topdir = os.path.dirname(os.path.abspath("__file__"))
analysis_dir = os.path.join(topdir,"analysis_root_files")

#dataver = "v003"
#dataver = "v004"
dataver = "v005"

firstPass = False

rootNameM127 = os.path.join(analysis_dir,"crvaging_module127_"+dataver+".root")
pdfNameM127 = os.path.join(analysis_dir,"crvaging_module127_"+dataver+".pdf")
FEBList127 = [0, 1]
rootNameM168 = os.path.join(analysis_dir,"crvaging_module168_"+dataver+".root")
pdfNameM168 = os.path.join(analysis_dir,"crvaging_module168_"+dataver+".pdf")
FEBList168 = [1, 2]
taskList = [(rootNameM127, pdfNameM127, FEBList127), (rootNameM168, pdfNameM168, FEBList168)]

refitList = []
if dataver == "v004":
    refitList = [(168,1146,0,2,13)] # 004

fitThres = 2400
# fitmin = [20., 40]
# fitmax = [100., 200]

def LandauGaussFunction(x, par):
    # From recoCrv::double LandauGaussFunction(double *x, double *par) 
    # From $ROOTSYS/tutorials/fit/langaus.C
    # Fit parameters:
    # par[0]=Width (scale) parameter of Landau density
    # par[1]=Most Probable (MP, location) parameter of Landau density
    # par[2]=Total area (integral -inf to inf, normalization constant)
    # par[3]=Width (sigma) of convoluted Gaussian function
    
    # In the Landau distribution (represented by the CERNLIB approximation),
    # the maximum is located at x=-0.22278298 with the location parameter=0.
    # This shift is corrected within this function, so that the actual
    # maximum is identical to the MP parameter.

    #  Numeric constants
    invsq2pi = 0.3989422804014   # (2 pi)^(-1/2)
    mpshift  = -0.22278298       # Landau maximum location

    # Control constants
    np = 100.0      # number of convolution steps
    sc =   5.0      # convolution extends to +-sc Gaussian sigmas

    # Variables
    xx = 0.0
    mpc = 0.0
    fland = 0.0
    sum_val = 0.0
    xlow = 0.0
    xupp = 0.0
    step = 0.0
    
    # MP shift correction
    mpc = par[1] - mpshift * par[0]

    # Range of convolution integral
    xlow = x[0] - sc * par[3]
    xupp = x[0] + sc * par[3]
    step = (xupp - xlow) / np

    # Convolution integral of Landau and Gaussian by sum
    for i in range(1, int(np/2) + 1):
        xx = xlow + (i - 0.5) * step
        fland = ROOT.TMath.Landau(xx, mpc, par[0]) / par[0]
        sum_val += fland * ROOT.TMath.Gaus(x[0], xx, par[3])

        xx = xupp - (i - 0.5) * step
        fland = ROOT.TMath.Landau(xx, mpc, par[0]) / par[0]
        sum_val += fland * ROOT.TMath.Gaus(x[0], xx, par[3])

    return par[2] * step * sum_val * invsq2pi / par[3]

def evaluateModule(rootname, pdfname, FEBList):
    
    moduleNum = int(pdfname[-12:-9])
    
    fC = ROOT.TCanvas("c%i"%moduleNum, "c%i"%moduleNum, 1600, 900)
    fC.Print(pdfname+"[", "pdf")
           
    fFile = ROOT.TFile(rootname, "READ")
    
    fROOTtempStorage = None
    if firstPass:
        fROOTtempStorage = ROOT.TFile(rootname[:-5]+"_tempStorage.root", "RECREATE")
    else:
        fROOTtempStorage = ROOT.TFile(rootname[:-5]+"_tempStorage.root", "READ")
    subrun_summary_tree = fFile.Get('subrun_summary')
    nSubruns = subrun_summary_tree.GetEntries()
    fFile.cd()
    
    t0 = None
    
    gStyle.SetOptStat(111110)
    fGraphAging = [[None]*geometry_constants.nChannelPerFEB for i in range(len(FEBList))]
    fGraphCMBTemp = [[None]*geometry_constants.nChannelPerFEB for i in range(len(FEBList))]
    fGrpahSPECorrected = [[None]*geometry_constants.nChannelPerFEB for i in range(len(FEBList))]
    SPECorrected_FEBVertical = [[[] for j in range(geometry_constants.nChannelPerFEB)] for i in range(len(FEBList))]
    fHistAging = [None]*len(FEBList)
    
    for ii in range(len(FEBList)):
        iFEB = FEBList[ii]
        fHistAging[ii] = ROOT.TH1F("hist_aging_rate_%i_%i"%(moduleNum, iFEB),
                                   "Module %i aging rate; aging rate [%%]; count"%(moduleNum),
                                   50, 0., 10.)
        for iCh in range(geometry_constants.nChannelPerFEB):
            fGraphAging[ii][iCh] = ROOT.TGraphErrors()
            fGraphAging[ii][iCh].SetName("fGraphAging_Module%i_FEB%i_Ch%i"%(moduleNum,iFEB,iCh))
            fGraphAging[ii][iCh].SetTitle("Module%i FEB%i Ch%i corrected light yield; Time [year]; Light yield [PE]"%(moduleNum,iFEB,iCh))
            fGraphAging[ii][iCh].SetMarkerStyle(1)
            fGraphAging[ii][iCh].SetMarkerColor(4)
            fGraphAging[ii][iCh].SetLineColor(4)
            fGraphAging[ii][iCh].SetLineWidth(3)
            fGraphAging[ii][iCh].SetMarkerSize(1)

            fGraphCMBTemp[ii][iCh] = ROOT.TGraph()
            fGraphCMBTemp[ii][iCh].SetName("fGraphCMBTemp_Module%i_FEB%i_Ch%i"%(moduleNum,iFEB,iCh))
            fGraphCMBTemp[ii][iCh].SetTitle("Module%i FEB%i Ch%i CMB temperature; Time [year]; Temperature [degC]"%(moduleNum,iFEB,iCh))
            fGraphCMBTemp[ii][iCh].SetMarkerStyle(21)
            fGraphCMBTemp[ii][iCh].SetMarkerColor(4)
            fGraphCMBTemp[ii][iCh].SetLineColor(4)
            fGraphCMBTemp[ii][iCh].SetLineWidth(3)
            fGraphCMBTemp[ii][iCh].SetMarkerSize(1)

            fGrpahSPECorrected[ii][iCh] = ROOT.TGraph()
            fGrpahSPECorrected[ii][iCh].SetName("fGrpahSPECorrected_Module%i_FEB%i_Ch%i"%(moduleNum,iFEB,iCh))
            fGrpahSPECorrected[ii][iCh].SetTitle("Module%i FEB%i Ch%i corrected SPE; Time [year]; Corrected SPE [ADC*ns/PE]"%(moduleNum,iFEB,iCh))
            fGrpahSPECorrected[ii][iCh].SetMarkerStyle(21)
            fGrpahSPECorrected[ii][iCh].SetMarkerColor(4)
            fGrpahSPECorrected[ii][iCh].SetLineColor(4)
            fGrpahSPECorrected[ii][iCh].SetLineWidth(3)
            fGrpahSPECorrected[ii][iCh].SetMarkerSize(1)
    
    hist_calibAdj_sigma = ROOT.TH1F("hist_calibAdj_sigma", "#sigma of Adjusted SPE (Vertical FEB Orientation); #sigma_{SPE} [ADC*ns/PE]; counts", 40, 0., 8.)
    hist_calibAdj_sigma_mu = ROOT.TH1F("hist_calibAdj_sigma_mu", "#sigma/#mu of Adjusted SPE (Vertical FEB Orientation); #sigma_{SPE}/#mu_{SPE}; counts", 40, 0., 0.02)
    tsEpochVeticalFEB = 1664928000 # 2022-10-5, when rack was installed
    
    for iSubrun in range(nSubruns):
        subrun_summary_tree.GetEntry(iSubrun)
        runNum = subrun_summary_tree.runNum
        subrunNum = subrun_summary_tree.subrunNum
    
        tsEpochStart = subrun_summary_tree.tsEpochStart
        tsEpochEnd = subrun_summary_tree.tsEpochEnd
        tYearRaw = (tsEpochEnd+tsEpochStart)/2./60./60./24./365.
        tYear_err = (tsEpochEnd-tsEpochStart)/2./60./60./24./365.
        
        if t0 is None:
            t0 = tYearRaw
            tYear = 0.
        else:
            tYear = tYearRaw-t0
            
        isVertical = True if tsEpochStart > tsEpochVeticalFEB else False
        
        lock.acquire()
        print("Processing Run%04i_%03i"%(runNum, subrunNum))
        if tYear_err>0.1:
            print(tsEpochStart/2./60./60./24./365., tsEpochEnd/2./60./60./24./365., tYear, tYear_err)
        sys.stdout.flush()
        lock.release()
        
        myfunc = [[None]*geometry_constants.nChannelPerFEB for i in range(len(FEBList))]
        fitfunc = [[None]*geometry_constants.nChannelPerFEB for i in range(len(FEBList))]
                
        for ii in range(len(FEBList)):
            iFEB = FEBList[ii]
            if (runNum, subrunNum) in manualDQC.manual_CMB_temp_exclusion_dict:
                if iFEB in manualDQC.manual_CMB_temp_exclusion_dict[(runNum, subrunNum)]:
                    continue
            
            for iCh in range(geometry_constants.nChannelPerFEB):
                fC.Clear()                
                index = iFEB * geometry_constants.nChannelPerFEB + iCh
                                  
                tSpectrumName = subrun_summary_tree.spectrumCorrected[index]
                
                tSpectrum = None
                if firstPass:
                    tSpectrum = fFile.Get(tSpectrumName).Clone()
                else:
                    tSpectrum = fROOTtempStorage.Get(tSpectrumName.split('/')[1]).Clone()
                
                maxbin = 0
                secondmaxbin = 0
                thirdmaxbin = 0
                maxbinContent = 0
                nHits = 0
                for ibin in range(6, tSpectrum.GetNbinsX()): # ignore first few bins that are noise peaks
                    binContent = tSpectrum.GetBinContent(ibin)
                    nHits += binContent
                    if binContent > maxbinContent:
                        thirdmaxbin=secondmaxbin
                        secondmaxbin=maxbin
                        maxbin=ibin
                        maxbinContent=binContent
                
                tSpectrum.SetMaximum(maxbinContent*1.2)
                tSpectrum.Draw()
                tPT = ROOT.TPaveText(.7, .4, .9, .72, "NDC")
                tPT.SetFillColor(0)
                tPT.AddText("%i hits #geq 5 PE"%nHits)
                
                peakrough = (maxbin+secondmaxbin+thirdmaxbin)/3.
                fitmin = peakrough/1.5
                fitmax = peakrough*2.4
                           
                # fit landgaus
                if nHits > fitThres:
                    
                    funcName = None                    
                    if firstPass or (moduleNum,runNum,subrunNum,iFEB,iCh) in refitList:
                        
                        myfunc[ii][iCh] = LandauGaussFunction
                        funcName = "func_Run%06i_%03i_FEB%02i_Ch%02i"%(runNum,subrunNum,iFEB,iCh)
                        
                        if (not firstPass) and ((moduleNum,runNum,subrunNum,iFEB,iCh) in refitList):
                            print("Refitting Run%06i_%03i_FEB%02i_Ch%02i"%(runNum,subrunNum,iFEB,iCh))
                            tempfunc = fROOTtempStorage.Get(funcName).Clone()
                            fitmin = tempfunc.GetParameter(1)/1.5
                            fitmax = tempfunc.GetParameter(1)*2.4
                            maxbin = tempfunc.GetParameter(1)
                        
                        fitfunc[ii][iCh] = ROOT.TF1(funcName, myfunc[ii][iCh], fitmin, fitmax, 4)
                        fitfunc[ii][iCh].SetParameter(0, 3.5 if moduleNum == 127 else 4.5)
                        fitfunc[ii][iCh].SetParameter(1, float(maxbin))
                        fitfunc[ii][iCh].SetParameter(2, float(nHits))
                        fitfunc[ii][iCh].SetParameter(3, 8. if moduleNum == 127 else 10.)
                        fitfunc[ii][iCh].SetParName(0, "Width")
                        fitfunc[ii][iCh].SetParName(1, "MP")
                        fitfunc[ii][iCh].SetParName(2, "Area")
                        fitfunc[ii][iCh].SetParName(3, "#sigma_{gaus}")
                        fitfunc[ii][iCh].SetParLimits(0, 1., 30.)
                        fitfunc[ii][iCh].SetParLimits(1, maxbin-30., maxbin+30.)
                        fitfunc[ii][iCh].SetParLimits(2, 0.01*nHits, 100.*nHits)
                        fitfunc[ii][iCh].SetParLimits(3, 0.5, 30.)
                        # print("Fitting FEB%i Ch%i"%(iFEB, iCh))
                        frp = tSpectrum.Fit(fitfunc[ii][iCh], "QRSL0")
                    else:
                        funcName = "func_Run%06i_%03i_FEB%02i_Ch%02i"%(runNum,subrunNum,iFEB,iCh)
                        fitfunc[ii][iCh] = fROOTtempStorage.Get(funcName).Clone()
                    
                    fitfunc[ii][iCh].SetLineColor(2)
                    fitfunc[ii][iCh].SetLineWidth(1)
                    fitfunc[ii][iCh].DrawClone("SAME")
                    
                    tPT.AddText("time in year %.3f"%(tYear))
                    tPT.AddText("#chi^{2}/NDF = %.3f/%i"%(fitfunc[ii][iCh].GetChisquare(), fitfunc[ii][iCh].GetNDF()))
                    tPT.AddText("Width = %.3f #pm %.3f"%(fitfunc[ii][iCh].GetParameter(0),fitfunc[ii][iCh].GetParError(0)))
                    tPT.AddText("MP = %.3f #pm %.3f"%(fitfunc[ii][iCh].GetParameter(1),fitfunc[ii][iCh].GetParError(1)))
                    tPT.AddText("Area = %.3f #pm %.3f"%(fitfunc[ii][iCh].GetParameter(2),fitfunc[ii][iCh].GetParError(2)))
                    tPT.AddText("#sigma_{gaus} = %.3f #pm %.3f"%(fitfunc[ii][iCh].GetParameter(3),fitfunc[ii][iCh].GetParError(3)))
                    
                    if fitfunc[ii][iCh].GetNDF()>0.: # ignore failed fittings
                        iPoint = fGraphAging[ii][iCh].GetN()
                        fGraphAging[ii][iCh].SetPoint(iPoint,tYear,fitfunc[ii][iCh].GetParameter(1))
                        fGraphAging[ii][iCh].SetPointError(iPoint,tYear_err,fitfunc[ii][iCh].GetParError(1))
                    else: 
                        print("Bad fit %i Run%04i_%03i FEB%i Ch%i"%(moduleNum, runNum, subrunNum, iFEB, iCh))
                
                tPT.DrawClone("SAME")
                fC.Print(pdfname, "Title: Run%04i_%03i FEB%i Ch%i"%(runNum, subrunNum, iFEB, iCh))
                
                fGraphCMBTemp[ii][iCh].SetPoint(fGraphCMBTemp[ii][iCh].GetN(),tYear,subrun_summary_tree.temperatureCMB[index])
                fGrpahSPECorrected[ii][iCh].SetPoint(fGrpahSPECorrected[ii][iCh].GetN(),tYear,subrun_summary_tree.calibAdj[index])
                
                if isVertical:
                    if subrun_summary_tree.calibAdj[index] > 0:
                        SPECorrected_FEBVertical[ii][iCh].append(subrun_summary_tree.calibAdj[index])
                    
                if firstPass:
                    fROOTtempStorage.cd()
                    if fitfunc[ii][iCh]:
                        fitfunc[ii][iCh].Write()
                    if tSpectrum:
                        tSpectrum.Write()
             
    fROOTtempStorage.Close()
    
    gStyle.SetOptStat(111110)
    hist_chi2perdof = ROOT.TH1F("hist_chi2perdof", "#chi^{2}/NDF of Aging Fits; #chi^{2}/NDF; counts", 50, 0., 10.)
    
    fC1 = ROOT.TCanvas("fC1%i"%moduleNum, "fC1%i"%moduleNum, 2*1600, 2*900)
    fC1.Divide(2, 2, 0.001, 0.001)
    for ii in range(len(FEBList)):
        iFEB = FEBList[ii]
        for iCh in range(geometry_constants.nChannelPerFEB):
            fC1.Clear("D")
            
            fC1.cd(1)
            gStyle.SetOptStat(0)
            gStyle.SetOptFit(111)
            fGraphAging[ii][iCh].DrawClone("AP")
            funcAging = ROOT.TF1("funcAging_%i_%i_%i"%(moduleNum,iFEB,iCh),"[0]*TMath::Power(1.-[1]/100., x)", -0.5, 5)
            funcAging.SetParameter(0, fGraphAging[ii][iCh].GetPointY(0))
            funcAging.SetParameter(1, 5)
            funcAging.SetParName(0, "PE_0")
            funcAging.SetParName(1, "Aging Rate")
            frp = fGraphAging[ii][iCh].Fit(funcAging, "QRS")
            funcAging.SetLineColor(2) # kRed
            funcAging.DrawClone("SAME")
            if funcAging.GetNDF()>0 and funcAging.GetParameter(1)>0.:
                fHistAging[ii].Fill(funcAging.GetParameter(1))
            tPT = ROOT.TPaveText(.7, .6, .95, .9, "NDC")
            tPT.SetFillColor(0)
            tPT.AddText("Fitting with A*pow(1-r/100, x)")
            tPT.AddText("#chi^{2}/NDF = %.3f/%i"%(funcAging.GetChisquare(), funcAging.GetNDF()))
            tPT.AddText("A = %.3f #pm %.3f"%(funcAging.GetParameter(0),funcAging.GetParError(0)))
            tPT.AddText("r = %.3f #pm %.3f"%(funcAging.GetParameter(1),funcAging.GetParError(1)))
            tPT.Draw("SAME")
            
            if funcAging.GetNDF()<=0:
                print(iFEB, iCh, funcAging.GetChisquare(), funcAging.GetNDF())
            else:
                hist_chi2perdof.Fill(funcAging.GetChisquare()/float(funcAging.GetNDF()))
        
            fC1.cd(2)
            gStyle.SetOptStat(0)
            gStyle.SetOptFit(0)
            fGraphCMBTemp[ii][iCh].Draw("ALP")
            
            fC1.cd(3)
            gStyle.SetOptStat(0)
            gStyle.SetOptFit(0)
            fGrpahSPECorrected[ii][iCh].Draw("ALP")
            
            fC1.Print(pdfname, "Title: FEB%i Ch%i summary"%(iFEB, iCh))
    
    gStyle.SetOptStat(111110)
    fC = ROOT.TCanvas("csummary%i"%moduleNum, "csummary%i"%moduleNum, 2*1600, 2*900)
    fC.Divide(2, 2, 0.001, 0.001)
    
    fC.cd(1)
    gStyle.SetOptStat(0)
    gStyle.SetOptFit(0)
    fStack = ROOT.THStack("stack_aging", "Module %i aging rate; aging rate [%%]; count"%(moduleNum))
    fLegend = ROOT.TLegend(0.7, 0.7, 0.95, 0.9)
    for ii in range(len(FEBList)):
        iFEB = FEBList[ii]
        fHistAging[ii].SetLineColor(constants.rootcolors[ii])
        fStack.Add(fHistAging[ii])
        fLegend.AddEntry(fHistAging[ii],"FEB %i: #mu = %.3f, #sigma = %.3f"%(iFEB, fHistAging[ii].GetMean(), fHistAging[ii].GetRMS()))
    fStack.Draw("NOSTACK")
    fLegend.Draw("SAME")
    
    fC.cd(2)
    gStyle.SetOptStat(111110)
    gStyle.SetOptFit(0)
    gROOT.ForceStyle()
    hist_chi2perdof.Draw()
    
    fC.cd(3)
    gStyle.SetOptStat(111110)
    gStyle.SetOptFit(0)
    gROOT.ForceStyle()
    for ii in range(len(FEBList)):
        for iCh in range(geometry_constants.nChannelPerFEB):
            hist_calibAdj_sigma.Fill(np.std(np.array(SPECorrected_FEBVertical[ii][iCh])))
    hist_calibAdj_sigma.Draw()
    
    fC.cd(4)
    gStyle.SetOptStat(111110)
    gStyle.SetOptFit(0)
    gROOT.ForceStyle()
    for ii in range(len(FEBList)):
        for iCh in range(geometry_constants.nChannelPerFEB):
            hist_calibAdj_sigma_mu.Fill(np.std(np.array(SPECorrected_FEBVertical[ii][iCh]))/np.mean(np.array(SPECorrected_FEBVertical[ii][iCh])))
    hist_calibAdj_sigma_mu.Draw()
    
    fC.Print(pdfname+")", "Title: Module %i aging"%moduleNum)  
    
    fFile.Close()
    return


nWorker = 2
p = mp.Pool(processes=nWorker)
for taskspec in taskList:
    p.apply_async(evaluateModule, (taskspec[0],taskspec[1],taskspec[2]))
p.close()
p.join()
'''
for ii in range(len(taskList)):
# for ii in range(1,2):
    evaluateModule(taskList[ii][0], taskList[ii][1], taskList[ii][2])
'''
# Out:
# Processing Run0066_000
# Processing Run1059_000
# Processing Run0066_001
# Processing Run1080_000
# Processing Run0094_000
# Processing Run1081_000
# Processing Run0094_001
# Processing Run0094_002
# Processing Run1082_000
# Processing Run0094_003
# Processing Run1091_000
# Processing Run0094_004
# Processing Run0094_005
# Processing Run1146_000
# Processing Run0094_006
# Processing Run0094_007
# Processing Run1148_000
# Processing Run0094_008
# Processing Run1149_000
# Processing Run0094_009
# Processing Run0094_010
# Processing Run0094_011
# Processing Run1150_000
# Processing Run0105_000
# Processing Run0105_001
# Processing Run0105_002
# Processing Run1152_000
# Processing Run0105_003
# Processing Run0105_004
# Processing Run1154_000
# Processing Run0105_005
# Processing Run0105_006
# Processing Run0105_007
# Processing Run1159_000
# Processing Run0105_008
# Processing Run0105_009
# Processing Run0119_000
# Processing Run1160_000
# Processing Run1010_000
# Processing Run1161_000
# Processing Run1020_000
# Processing Run1021_000
# Processing Run1167_000
# Processing Run1022_000
# Processing Run1168_000
# Processing Run1022_001
# Processing Run1031_000
# Processing Run1169_000
# Processing Run1033_000
# Processing Run1170_000
# Processing Run1033_001
# Processing Run1034_000
# Processing Run1171_000
# Processing Run1034_001
# Processing Run1177_000
# Processing Run1034_002
# Processing Run1034_003
# Processing Run1181_000
# Processing Run1035_000
# Processing Run1243_000
# Processing Run1212_000
# Processing Run1244_000
# Processing Run1212_001
# Processing Run1245_000
# Processing Run1246_000
# Processing Run1217_000
# Processing Run1247_000
# Processing Run1248_000
# Processing Run1218_000
# Processing Run1251_000
# Processing Run1262_000
# Processing Run1219_000
# Bad fit 168 Run1219_000 FEB1 Ch47
# Processing Run1264_000
# Bad fit 127 Run1264_000 FEB0 Ch61
# Processing Run1240_000
# Processing Run1276_000
# Processing Run1279_000
# Processing Run1279_001
# Processing Run1241_000
# Processing Run1279_002
# Processing Run1279_003
# Processing Run1279_004
# Processing Run1279_005
# Processing Run1279_006
# Processing Run1279_007
# Processing Run1375_000
# Processing Run1280_000
# Processing Run1280_001
# Processing Run1280_002
# Processing Run1376_000
# Processing Run1281_000
# Processing Run1281_001
# Processing Run1281_002
# Processing Run1281_003
# Processing Run1376_001
# Processing Run1281_004
# Processing Run1281_005
# Processing Run1284_000
# Processing Run1379_000
# Processing Run1284_001
# Processing Run1285_000
# Processing Run1380_000
# Processing Run1285_001
# Processing Run1400_000
# Processing Run1286_000
# Processing Run1287_000
# Bad fit 127 Run1287_000 FEB0 Ch60
# Bad fit 127 Run1287_000 FEB0 Ch61
# Processing Run1407_000
# Processing Run1288_000
# Processing Run1312_000
# Processing Run1407_001
# Processing Run1312_001
# Processing Run1407_002
# Processing Run1312_002
# Processing Run1315_000
# Processing Run1315_001
# Processing Run1327_000
# Processing Run1341_000
# Processing Run1341_002
# Processing Run1341_003
# Processing Run1341_004
# Processing Run1341_005
# Processing Run1354_000
# Processing Run1354_001
# Processing Run1370_000
# 0 30 6.312571760153373e-07 0
# 0 31 4.397512262201699e-07 0
# 0 60 4.548611808184187e-13 0
# 0 61 0.0 0
# 0 62 0.0 0
# 0 63 0.0 0
# '\nfor ii in range(len(taskList)):\n# for ii in range(1,2):\n    evaluateModule(taskList[ii][0], taskList[ii][1], taskList[ii][2])\n'
# Warning in <Fit>: Fit data is empty
# Warning in <Fit>: Fit data is empty
# Warning in <Fit>: Fit data is empty
